# %% [markdown]
# # What is AutoNLP?
#
#
#
# ![image.png](attachment:d5b47a9b-73e2-4b62-b032-4e461b322c4a.png)
#
# AutoNLP is very similar to AutoML, it automates the process of EDA and text processing and helps data scientists to get the best model. AutoNLP is a function present in the AutoViML framework, built using scikit-learn, NumPy, pandas, and matplotlib. It is designed to build high-performance interpretable models with the fewest variables.
#
# AutoNLP guides a data scientist in:
# * Exploratory data analysis of text
# * Data Cleaning
# * Feature reduction
# * Variable Classification
# * Produces model performance results as graphs
# * Can easily handle text, date-time, structs, numeric, boolean, factor, and categorical variables
# * Allows use the featuretools library to do Feature Engineering
#
# ```
# from autoviml.feature_engineering import feature_engineering
# print(df[preds].shape)
# dfmod = feature_engineering(df[preds],['add'],'ID')
# print(dfmod.shape)
# ```

# %% [markdown]
# # Case Study

# %% [markdown]
# ## 1. Install autoviml

# %%
# !pip install autoviml
# Out:
# Collecting autoviml
#   Downloading autoviml-0.1.682-py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 830 kB/s
# Requirement already satisfied: catboost in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.26)
# Requirement already satisfied: xgboost>=1.1.1 in /opt/conda/lib/python3.7/site-packages (from autoviml) (1.4.2)
# Requirement already satisfied: shap>=0.36.0 in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.39.0)
# Requirement already satisfied: textblob in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.15.3)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#      |████████████████████████████████| 125 kB 2.4 MB/s
# Requirement already satisfied: ipython in /opt/conda/lib/python3.7/site-packages (from autoviml) (7.24.1)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.7/site-packages (from autoviml) (3.4.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.7/site-packages (from autoviml) (4.9.3)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.7/site-packages (from autoviml) (1.2.4)
# Collecting xlrd
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 1.9 MB/s
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.11.1)
# Requirement already satisfied: jupyter in /opt/conda/lib/python3.7/site-packages (from autoviml) (1.0.0)
# Requirement already satisfied: emoji in /opt/conda/lib/python3.7/site-packages (from autoviml) (1.2.0)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.7/site-packages (from autoviml) (3.2.4)
# Requirement already satisfied: scikit-learn>=0.23.1 in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.23.2)
# Requirement already satisfied: regex in /opt/conda/lib/python3.7/site-packages (from autoviml) (2021.4.4)
# Requirement already satisfied: imbalanced-learn>=0.7 in /opt/conda/lib/python3.7/site-packages (from autoviml) (0.8.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.7/site-packages (from imbalanced-learn>=0.7->autoviml) (1.6.3)
# Requirement already satisfied: numpy>=1.13.3 in /opt/conda/lib/python3.7/site-packages (from imbalanced-learn>=0.7->autoviml) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from imbalanced-learn>=0.7->autoviml) (1.0.1)
# Collecting scikit-learn>=0.23.1
#   Downloading scikit_learn-0.24.2-cp37-cp37m-manylinux2010_x86_64.whl (22.3 MB)
#      |████████████████████████████████| 22.3 MB 198 kB/s
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from scikit-learn>=0.23.1->autoviml) (2.1.0)
# Requirement already satisfied: numba in /opt/conda/lib/python3.7/site-packages (from shap>=0.36.0->autoviml) (0.53.1)
# Requirement already satisfied: cloudpickle in /opt/conda/lib/python3.7/site-packages (from shap>=0.36.0->autoviml) (1.6.0)
# Requirement already satisfied: tqdm>4.25.0 in /opt/conda/lib/python3.7/site-packages (from shap>=0.36.0->autoviml) (4.61.1)
# Requirement already satisfied: slicer==0.0.7 in /opt/conda/lib/python3.7/site-packages (from shap>=0.36.0->autoviml) (0.0.7)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.7/site-packages (from beautifulsoup4->autoviml) (2.2.1)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.7/site-packages (from catboost->autoviml) (0.8.4)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from catboost->autoviml) (1.15.0)
# Requirement already satisfied: plotly in /opt/conda/lib/python3.7/site-packages (from catboost->autoviml) (5.1.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.7/site-packages (from pandas->autoviml) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/lib/python3.7/site-packages (from pandas->autoviml) (2021.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (3.0.19)
# Requirement already satisfied: backcall in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (49.6.0.post20210108)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (4.8.0)
# Requirement already satisfied: pygments in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (2.9.0)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (5.0.9)
# Requirement already satisfied: pickleshare in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (0.18.0)
# Requirement already satisfied: traitlets>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (5.0.5)
# Requirement already satisfied: matplotlib-inline in /opt/conda/lib/python3.7/site-packages (from ipython->autoviml) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/conda/lib/python3.7/site-packages (from jedi>=0.16->ipython->autoviml) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.7/site-packages (from pexpect>4.3->ipython->autoviml) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->autoviml) (0.2.5)
# Requirement already satisfied: ipython-genutils in /opt/conda/lib/python3.7/site-packages (from traitlets>=4.2->ipython->autoviml) (0.2.0)
# Requirement already satisfied: ipykernel in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (5.5.5)
# Requirement already satisfied: nbconvert in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (6.0.7)
# Requirement already satisfied: qtconsole in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (5.1.1)
# Requirement already satisfied: notebook in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (6.4.0)
# Requirement already satisfied: jupyter-console in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (6.4.0)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.7/site-packages (from jupyter->autoviml) (7.6.3)
# Requirement already satisfied: tornado>=4.2 in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter->autoviml) (6.1)
# Requirement already satisfied: jupyter-client in /opt/conda/lib/python3.7/site-packages (from ipykernel->jupyter->autoviml) (6.1.12)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->jupyter->autoviml) (1.0.0)
# Requirement already satisfied: nbformat>=4.2.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->jupyter->autoviml) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /opt/conda/lib/python3.7/site-packages (from ipywidgets->jupyter->autoviml) (3.5.1)
# Requirement already satisfied: jupyter-core in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (4.7.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /opt/conda/lib/python3.7/site-packages (from nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (3.2.0)
# Requirement already satisfied: importlib-metadata in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (3.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.7/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (21.2.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (3.0.1)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (0.10.1)
# Requirement already satisfied: pyzmq>=17 in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (22.1.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (1.5.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (0.11.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.7/site-packages (from notebook->jupyter->autoviml) (20.1.0)
# Requirement already satisfied: cffi>=1.0.0 in /opt/conda/lib/python3.7/site-packages (from argon2-cffi->notebook->jupyter->autoviml) (1.14.5)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.7/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->jupyter->autoviml) (2.20)
# Requirement already satisfied: zipp>=0.5 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (3.4.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in /opt/conda/lib/python3.7/site-packages (from importlib-metadata->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets->jupyter->autoviml) (3.7.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.7/site-packages (from jinja2->notebook->jupyter->autoviml) (2.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autoviml) (1.3.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autoviml) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autoviml) (8.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.7/site-packages (from matplotlib->autoviml) (0.10.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.5.3)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (3.3.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.1.2)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.7.1)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.5.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (1.4.2)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.8.4)
# Requirement already satisfied: entrypoints>=0.2.2 in /opt/conda/lib/python3.7/site-packages (from nbconvert->jupyter->autoviml) (0.3)
# Requirement already satisfied: async-generator in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviml) (1.10)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.7/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->jupyter->autoviml) (1.5.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->autoviml) (20.9)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.7/site-packages (from bleach->nbconvert->jupyter->autoviml) (0.5.1)
# Requirement already satisfied: llvmlite<0.37,>=0.36.0rc1 in /opt/conda/lib/python3.7/site-packages (from numba->shap>=0.36.0->autoviml) (0.36.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/lib/python3.7/site-packages (from plotly->catboost->autoviml) (7.0.0)
# Requirement already satisfied: qtpy in /opt/conda/lib/python3.7/site-packages (from qtconsole->jupyter->autoviml) (1.9.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from vaderSentiment->autoviml) (2.25.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->vaderSentiment->autoviml) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->vaderSentiment->autoviml) (2021.5.30)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->vaderSentiment->autoviml) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->vaderSentiment->autoviml) (1.26.5)
# Installing collected packages: scikit-learn, xlrd, vaderSentiment, autoviml
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.23.2
#     Uninstalling scikit-learn-0.23.2:
#       Successfully uninstalled scikit-learn-0.23.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pyldavis 3.3.1 requires numpy>=1.20.0, but you have numpy 1.19.5 which is incompatible.
# pdpbox 0.2.1 requires matplotlib==3.1.1, but you have matplotlib 3.4.2 which is incompatible.
# hypertools 0.7.0 requires scikit-learn!=0.22,<0.24,>=0.19.1, but you have scikit-learn 0.24.2 which is incompatible.
# Successfully installed autoviml-0.1.682 scikit-learn-0.24.2 vaderSentiment-3.3.2 xlrd-2.0.1
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2. Loading data

# %%
data = pd.read_csv('../input/twitter-sentiment-analysis-hatred-speech/train.csv')

# %%
data.head()
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %% [markdown]
# ## 3. Usage

# %%
from sklearn.model_selection import train_test_split

from autoviml.Auto_NLP import Auto_NLP

train, test = train_test_split(data, test_size=0.2)
# Out:
# Imported Auto_ViML version: 0.1.682. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.0.46.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# ## 4. Specifying the Response and Predictor variables

# %%
input_feature, target = "tweet", "label"

# %% [markdown]
# ## 5. Run AutoNLP

# %%
train_x, test_x, final, predicted= Auto_NLP(input_feature, train, test,target,
                                            score_type="balanced_accuracy",
                                            top_num_features=100,
                                            modeltype="Classification",
                                            verbose=2,
                                            build_model=True)
# Out:
# [nltk_data] Downloading collection 'popular'
# [nltk_data]    |
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package gazetteers to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package gazetteers is already up-to-date!
# [nltk_data]    | Downloading package genesis to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package genesis is already up-to-date!
# [nltk_data]    | Downloading package gutenberg to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package gutenberg is already up-to-date!
# [nltk_data]    | Downloading package inaugural to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package inaugural is already up-to-date!
# [nltk_data]    | Downloading package movie_reviews to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package movie_reviews is already up-to-date!
# [nltk_data]    | Downloading package names to /usr/share/nltk_data...
# [nltk_data]    |   Package names is already up-to-date!
# [nltk_data]    | Downloading package shakespeare to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package shakespeare is already up-to-date!
# [nltk_data]    | Downloading package stopwords to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package stopwords is already up-to-date!
# [nltk_data]    | Downloading package treebank to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package treebank is already up-to-date!
# [nltk_data]    | Downloading package twitter_samples to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package twitter_samples is already up-to-date!
# [nltk_data]    | Downloading package omw to /usr/share/nltk_data...
# [nltk_data]    |   Package omw is already up-to-date!
# [nltk_data]    | Downloading package wordnet to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet is already up-to-date!
# [nltk_data]    | Downloading package wordnet_ic to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package wordnet_ic is already up-to-date!
# [nltk_data]    | Downloading package words to /usr/share/nltk_data...
# [nltk_data]    |   Package words is already up-to-date!
# [nltk_data]    | Downloading package maxent_ne_chunker to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package maxent_ne_chunker is already up-to-date!
# [nltk_data]    | Downloading package punkt to /usr/share/nltk_data...
# [nltk_data]    |   Package punkt is already up-to-date!
# [nltk_data]    | Downloading package snowball_data to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package snowball_data is already up-to-date!
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /usr/share/nltk_data...
# [nltk_data]    |   Package averaged_perceptron_tagger is already up-
# [nltk_data]    |       to-date!
# [nltk_data]    |
# [nltk_data]  Done downloading collection popular
# Auto NLP processing on NLP Column: tweet
# Shape of Train Data: 25569 rows
#     Shape of Test Data: 6393 rows
#     Added 9 summary columns for counts of words and characters in each row
# Cleaning text in Train data for tweet column
#     Faster text processing using clean_text function, since top_num_features is below 300
#     Time Taken for Expanding emojis and abbreviations in data = 9 seconds
#         Time Taken for Processing text in data = 53 seconds
# Train data Text cleaning completed. Time taken = 71 seconds
#
# For target = label
#
#     For class = 0
# Top 200 n-grams
# : ['user', 'love', 'day', 'do', 'not', 'happy', 'positive', 'me', 'time', 'go', 'your', 'we', 'today', 'will', 'make', 'what', 'when', 'good', 'life', 'take', 'father', 'now', 'new', 'thankful', 'see', 'bihday', 'like', 'but', 'smile', 'our', 'look', 'how', 'cannot', 'people', 'healthy', 'want', 'ur', 'come', 'wait', 'affirmation', 'model', 'i_am', 'weekend', 'no', 'summer', 'week', 'work', 'family', 'way', 'fun', 'beautiful', 'friday', 'great', 'tomorrow', 'there', 'they', 'fathersday', 'best', 'first', 'feel', 'know', 'girl', 'friend', 'think', 'morning', 'here', 'need', 'who', 'year', 'watch', 'home', 'dad', 'if', 'he', 'thing', 'sunday', 'after', 'music', 'night', 'cute', 'back', 'find', 'really', 'world', 'why', 'happiness', 'much', 'well', 'thank', 'sad', 'right', 'altwaystoheal', 'always', 'follow', 'off', 'finally', 'tonight', 'live', 'orlando', 'never', 'blog', 'enjoy', 'next', 'her', 'play', 'selfie', 'everyone', 'their', 'god', 'show', 'last', 'thanks', 'ready', 'bull', 'his', 'pay', 'amazing', 'little', 'saturday', 'even', 'big', 'these', 'game', 'dog', 'them', 'place', 'as', 'let', 'blessed', 'would', 'friends', 'another', 'guy', 'user user', 'do not', 'father day', 'thankful positive', 'i_am positive', 'positive affirmation', 'take time', 'love take', 'model love', 'time ur', 'cannot wait', 'blog silver', 'silver gold', 'gold forex', 'make me', 'altwaystoheal healthy', 'happy father', 'happy bihday', 'user we', 'look forward', 'right now', 'laugh loud', 'user do', 'want do', 'look like', 'user happy', 'good morning', 'next week', 'user not', 'whatever want', 'user look', 'bull will', 'direct whatever', 'user user user', 'i_am positive affirmation', 'love take time', 'model love take', 'take time ur', 'blog silver gold', 'silver gold forex', 'happy father day', 'do not know', 'user do not', 'bull will direct', 'bull will dominate', 'direct whatever want', 'dominate your bull', 'whatever want do', 'will direct whatever', 'will dominate your', 'your bull will', 'do not want', 'user father day', 'grateful now affirmations', 'cannot wait see', 'want do when', 'bing bong bing', 'bong bing bong', 'good bing bong', 'yeah good bing', 'adapt environment need', 'do adapt environment', 'environment need tear', 'gorilla simulator need', 'need do adapt', 'need tear city']
#     Top n-grams that are most frequent in this class are: 199
#
#     For class = 1
# Top 200 n-grams
# : ['not', 'do', 'if', 'trump', 'white', 'black', 'politics', 'libtard', 'racist', 'liberal', 'might', 'like', 'sjw', 'woman', 'why', 'what', 'we', 'your', 'no', 'people', 'who', 'will', 'how', 'obama', 'his', 'allahsoil', 'feel', 'they', 'retweet', 'racism', 'but', 'call', 'listen', 'make', 'video', 'should', 'he', 'fuck', 'right', 'men', 'late', 'sex', 'when', 'hate', 'stomp', 'miami', 'thanks', 'man', 'want', 'girl', 'go', 'come', 'against', 'good', 'new', 'race', 'bigot', 'me', 'comment', 'her', 'our', 'tampa', 'would', 'american', 'because', 'year', 'never', 'here', 'america', 'show', 'word', 'great', 'blacklivesmatter', 'thing', 'stop', 'guy', 'play', 'love', 'malevote', 'their', 'world', 'cannot', 'naked', 'daily', 'news', 'feminismiscancer', 'feminismisterrorism', 'feminismmuktbharat', 'ignore', 'blm', 'anti', 'read', 'suppoers', 'president', 'even', 'look', 'porn', 'brexit', 'police', 'nothing', 'see', 'fear', 'muslim', 'kkk', 'she', 'many', 'live', 'mean', 'pay', 'always', 'teambts', 'feminism', 'school', 'hispanic', 'maga', 'end', 'act', 'now', 'point', 'enough', 'agree', 'lose', 'attack', 'talk', 'ny', 'african', 'back', 'may', 'him', 'hatred', 'also', 'w', 'please', 'user user', 'do not', 'user allahsoil', 'if libtard', 'liberal politics', 'libtard if', 'libtard sjw', 'might libtard', 'sjw liberal', 'user might', 'user no', 'user what', 'thanks user', 'feel like', 'user your', 'like stomp', 'listen retweet', 'black feel', 'retweet tampa', 'tampa miami', 'stomp listen', 'not racist', 'daily thanks', 'why do', 'michelle obama', 'user do', 'user why', 'white woman', 'white people', 'trump ally', 'user please', 'feminismiscancer feminismisterrorism', 'feminismisterrorism feminismmuktbharat', 'user user user', 'if libtard sjw', 'libtard if libtard', 'libtard sjw liberal', 'might libtard if', 'sjw liberal politics', 'user might libtard', 'feel like stomp', 'thanks user user', 'black feel like', 'retweet tampa miami', 'like stomp listen', 'stomp listen retweet', 'daily thanks user', 'listen retweet tampa', 'user user why', 'feminismiscancer feminismisterrorism feminismmuktbharat', 'feminismisterrorism feminismmuktbharat why', 'feminismmuktbharat why malevote', 'malevote ignore user', 'user feminismiscancer feminismisterrorism', 'why malevote ignore', 'sea shepherd suppoers', 'shepherd suppoers racist', 'happy new year', 'swiftly sharpen fang', 'racist antiracism seashepherd', 'suppoers racist antiracism', 'girl sex black', 'sex black guy', 'white girl sex', 'hispanic feel like', 'listen retweet boricua']
#     Top n-grams that are most frequent in this class are: 199
# Time Taken = 1 seconds
# ##################    THIS IS FOR BUILD_MODEL = TRUE           #################
# Building Model and Pipeline for NLP column = tweet. This will take time...
#        Class  -> Counts -> Percent
#            0:   23792  ->   93.1%
#            1:    1777  ->    6.9%
#     Selected the maximum number of features limit = 33384
# Performing RandomizedSearchCV across 30 params. Optimizing for accuracy
#     Using train data = (20455,) and Cross Validation data = (5114,)
# Using a Calibrated Classifier in this Multi_Classification dataset to improve results...
# Since top_num_features = 100, Multinomial NB model selected. If you need different model, increase it >= 300.
# Training completed. Time taken for training = 2.8 minutes
# Best Params of NLP pipeline are: {'multinomialnb__alpha': 0.07559798448165034, 'selectkbest__k': 11689, 'tfidfvectorizer__binary': False, 'tfidfvectorizer__encoding': 'utf-8', 'tfidfvectorizer__max_df': 0.7585975625559274}
# <style>.container { width:95% !important; }</style>
# <style>.container { width:95% !important; }</style>
#   Now transforming Train data to return as output...
#     Time Taken for Expanding emojis and abbreviations in data = 6 seconds
#         Time Taken for Processing text in data = 40 seconds
#   Transforming Test data to return as output...
#     Time Taken for Expanding emojis and abbreviations in data = 2 seconds
#         Time Taken for Processing text in data = 13 seconds
# Training best Auto_NLP Pipeline on full Train data...will be faster since best params are known
#     Time Taken for Expanding emojis and abbreviations in data = 6 seconds
#         Time Taken for Processing text in data = 40 seconds
#     Returning best Auto_NLP pipeline to transform and make predictions on test data...
#     Time Taken for Expanding emojis and abbreviations in data = 2 seconds
#         Time Taken for Processing text in data = 13 seconds
# Training completed. Time taken for Auto_NLP = 6.2 minutes
# #########          A U T O   N L P  C O M P L E T E D    ###############################

# %%
final.predict(test_x[input_feature])
# Out:
#     Time Taken for Expanding emojis and abbreviations in data = 2 seconds
#         Time Taken for Processing text in data = 13 seconds
# array([0, 0, 0, ..., 0, 0, 0])

# %% [markdown]
# ## 6. Prediction

# %%
testing = pd.read_csv('../input/twitter-sentiment-analysis-hatred-speech/test.csv')

# %%
final.predict(testing[input_feature])
# Out:
#     Time Taken for Expanding emojis and abbreviations in data = 6 seconds
#         Time Taken for Processing text in data = 35 seconds
# array([0, 0, 0, ..., 0, 0, 0])

# %%
prediction = pd.read_csv('../input/twitter-sentiment-analysis-hatred-speech/test.csv')

# %%
prediction['label'] = final.predict(testing[input_feature])
# Out:
#     Time Taken for Expanding emojis and abbreviations in data = 6 seconds
#         Time Taken for Processing text in data = 35 seconds

# %%
prediction.to_csv('prediction.csv',index = False)

# %% [markdown]
# # Reference :
#
# * https://github.com/AutoViML/Auto_ViML
